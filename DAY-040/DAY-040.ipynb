# %% [markdown]
# # Day-40 of 100dayofcode [24/08/2022 Wednesday]

# %% [markdown]
# # Namedtuple
# Python supports a type of container like dictionaries called “namedtuple()” present in the module, “collections“. Like dictionaries, they contain keys that are hashed to a particular value. But on contrary, it supports both access from key-value and iteration, the functionality that dictionaries lack.

# %%
from collections import namedtuple

# %%
employe = namedtuple("employe",['name','age','salary'])

# %%
e = employe(name='ayush',age=18,salary=78998565856878)

# %%
print(type(e),type(employe))
# Out:
# <class '__main__.employe'> <class 'type'>

# %%
print(e[1])
print(e[0])
print(e[2])
print(e.age)
# Out:
# 18
# ayush
# 78998565856878
# 18

# %% [markdown]
# ## getattr()
# using getattr(): This is yet another way to access the value by giving namedtuple and key value as its argument.

# %%
print(getattr(e,'age'))

# = e.age
# Out:
# 18

# %% [markdown]
# Conversion Operations
#
#     _make() :- This function is used to return a namedtuple() from the iterable passed as argument.
#     _asdict() :- This function returns the OrderedDict() as constructed from the mapped values of namedtuple().
#     using “**” (double star) operator :- This function is used to convert a dictionary into the namedtuple().

# %%
import collections

# %%
employe = namedtuple("employe",['name','age','salary'])
e = employe(name='ayush',age=18,salary=78998565856878)
e2 = ['ravi',45,546466546464]

# %%
print(employe._make(e2))
# Out:
# employe(name='ravi', age=45, salary=546466546464)

# %%
print(e._asdict())
# Out:
# {'name': 'ayush', 'age': 18, 'salary': 78998565856878}

# %%
# dic 
e3 = {"name":'dev','age':49,'salary':546465446560}
print(employe(**e3))
# Out:
# employe(name='dev', age=49, salary=546465446560)

# %% [markdown]
# Additional Operation
#
#     _fields: This function is used to return all the keynames of the namespace declared.
#     _replace(): _replace() is like str.replace() but targets named fields( does not modify the original values)

# %%
print(e._fields)
print(e._replace(age=48))
# Out:
# ('name', 'age', 'salary')
# employe(name='ayush', age=48, salary=78998565856878)

# %% [markdown]
# ## Deque
# Deque (Doubly Ended Queue) in Python is implemented using the module “collections“. Deque is preferred over a list in the cases where we need quicker append and pop operations from both the ends of the container, as deque provides an *O(1)* time complexity for append and pop operations as compared to a list that provides *O(n)* time complexity.

# %%
from IPython.display import Image
Image("https://media.geeksforgeeks.org/wp-content/uploads/anod.png")

# %% [markdown]
# **Types of Restricted Deque Input**
#
#     Input Restricted Deque:  Input is limited at one end while deletion is permitted at both ends.
#     Output Restricted Deque: output is limited at one end but insertion is permitted at both ends.

# %%
from collections import deque

# %%
queue  =  deque([1,2,3,4,5])

# %%
print(type(queue))
print(queue)
# Out:
# <class 'collections.deque'>
# deque([1, 2, 3, 4, 5])

# %% [markdown]
# ## Operations on deque
#     append():- This function is used to insert the value in its argument to the right end of the deque.
#     appendleft():- This function is used to insert the value in its argument to the left end of the deque.

# %%
print("Orignal deque: ",queue)

queue.append(6)

print("after append in deque: ",queue)

queue.appendleft(0)

print("after leftappend in deque: ",queue)
# Out:
# Orignal deque:  deque([1, 2, 3, 4, 5])
# after append in deque:  deque([1, 2, 3, 4, 5, 6])
# after leftappend in deque:  deque([0, 1, 2, 3, 4, 5, 6])

# %% [markdown]
# ### Popping Items Efficiently
#
#     pop():- This function is used to delete an argument from the right end of the deque.
#     popleft():- This function is used to delete an argument from the left end of the deque.

# %%
print("Orignal deque: ",queue)

queue.pop()

print("after pop from right hand: ",queue)

queue.popleft()

print("after pop from left hand ",queue)
# Out:
# Orignal deque:  deque([0, 1, 2, 3, 4, 5, 6])
# after pop from right hand:  deque([0, 1, 2, 3, 4, 5])
# after pop from left hand  deque([1, 2, 3, 4, 5])

# %% [markdown]
# ### Accessing Items in a deque
#
#     index(ele, beg, end):- This function returns the first index of the value mentioned in arguments, starting searching from beg till end index.
#     insert(i, a) :- This function inserts the value mentioned in arguments(a) at index(i) specified in arguments.
#     remove():- This function removes the first occurrence of the value mentioned in arguments.
#     count():- This function counts the number of occurrences of value mentioned in arguments.

# %%
new_queue = deque([1,1,1,2,2,3,4,5,6,6,6])

print("The Orignal Deque : ",new_queue,'\n')

print(len(new_queue))
# Out:
# The Orignal Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6])
#
# 11

# %%
print(new_queue.index(5,6,11))
print(new_queue[7]) # value on 7th index
# Out:
# 7
# 5

# %%
print("The Orignal Deque : ",new_queue,'\n')
new_queue.insert(12,9)
print("The After Deque : ",new_queue,'\n')
# Out:
# The Orignal Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6])
#
# The After Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 9])

# %%
print("The Orignal Deque : ",new_queue,'\n')
new_queue.insert(13,[54,4,5,78])
print("The After Deque : ",new_queue,'\n')
# Out:
# The Orignal Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 9])
#
# The After Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 9, [54, 4, 5, 78]])

# %%
print("The Orignal Deque : ",new_queue,'\n')
new_queue.insert(13,(7,8,9))
print("The After Deque : ",new_queue,'\n')
# Out:
# The Orignal Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 9, [54, 4, 5, 78]])
#
# The After Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 9, [54, 4, 5, 78], (7, 8, 9)])

# %%
print("The Orignal Deque : ",new_queue,'\n')
new_queue.remove(9)
print("The After Deque : ",new_queue,'\n')
# Out:
# The Orignal Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 9, [54, 4, 5, 78], (7, 8, 9)])
#
# The After Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, [54, 4, 5, 78], (7, 8, 9)])

# %%
print("The Orignal Deque : ",new_queue,'\n')
print(new_queue.count(1))
# Out:
# The Orignal Deque :  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, [54, 4, 5, 78], (7, 8, 9)])
#
# 3

# %% [markdown]
# ### Different operations on deque
#
#
#     extend(iterable):- This function is used to add multiple values at the right end of the deque. The argument passed is iterable.
#
#     extendleft(iterable):- This function is used to add multiple values at the left end of the deque. The argument passed is iterable. Order is reversed as a result of left appends.
#
#     reverse():- This function is used to reverse the order of deque elements.
#
#     rotate():- This function rotates the deque by the number specified in arguments. If the number specified is negative, rotation occurs to the left. Else rotation is to right.

# %%
print("Orignal deque: ",new_queue)

new_queue.extend([81,59,45,66])

print("after extend from right hand: ",new_queue)

new_queue.extendleft([-5,-4,-3,-2,-1])

print("after extend from left hand ",new_queue)
# Out:
# Orignal deque:  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6])
# after extend from right hand:  deque([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 81, 59, 45, 66])
# after extend from left hand  deque([-1, -2, -3, -4, -5, 1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 81, 59, 45, 66])

# %%
new_queue.reverse()

# %%
print(new_queue)
# Out:
# deque([66, 45, 59, 81, 6, 6, 6, 5, 4, 3, 2, 2, 1, 1, 1, -5, -4, -3, -2, -1])

# %%
print(new_queue)
new_queue.rotate(66)
# Out:
# deque([66, 45, 59, 81, 6, 6, 6, 5, 4, 3, 2, 2, 1, 1, 1, -5, -4, -3, -2, -1])

# %%
print(new_queue)
# Out:
# deque([1, -5, -4, -3, -2, -1, 66, 45, 59, 81, 6, 6, 6, 5, 4, 3, 2, 2, 1, 1])

# %%
new_queue.rotate(2)

# %%
print(new_queue)
# Out:
# deque([1, 1, 1, -5, -4, -3, -2, -1, 66, 45, 59, 81, 6, 6, 6, 5, 4, 3, 2, 2])

# %% [markdown]
# ## UserDict
#
# Python supports a dictionary like a container called UserDict present in the collections module. This class acts as a wrapper class around the dictionary objects. This class is useful when one wants to create a dictionary of their own with some modified functionality or with some new functionality. It can be considered as a way of adding new behaviors to the dictionary. This class takes a dictionary instance as an argument and simulates a dictionary that is kept in a regular dictionary. The dictionary is accessible by the data attribute of this class.

# %%
from collections import UserDict

# %%
# creating empty dict
ud = UserDict()
print(type(ud))
# Out:
# <class 'collections.UserDict'>

# %%
d ={'k1':'v1'}
ud1 = UserDict(d)

# %%
print(type(ud1))
# Out:
# <class 'collections.UserDict'>

# %%
print(ud1.data)
# Out:
# {'k1': 'v1'}

# %%
# custom ductionary

class custdict(UserDict):
    
    def pop(self,item=None):
        raise RuntimeError("YOU CANNOT DELETE TEH ELEMENT FORM THIS DICT")

# %%
d = custdict({"k1":'v1'})

# %%
d.pop()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 52 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y125sZmlsZQ%3D%3D?line=0'>1</a> d.pop()
#
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 52 in custdict.pop(self, item)
#       <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y125sZmlsZQ%3D%3D?line=4'>5</a> def pop(self,item=None):
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y125sZmlsZQ%3D%3D?line=5'>6</a>     raise RuntimeError("YOU CANNOT DELETE TEH ELEMENT FORM THIS DICT")
#
# RuntimeError: YOU CANNOT DELETE TEH ELEMENT FORM THIS DICT

# %% [markdown]
# ### UserList
#
# Python supports a List like a container called UserList present in the collections module. This class acts as a wrapper class around the List objects. This class is useful when one wants to create a list of their own with some modified functionality or with some new functionality. It can be considered as a way of adding new behaviors for the list. This class takes a list instance as an argument and simulates a list that is kept in a regular list. The list is accessible by the data attribute of the this class.

# %%
from collections import UserList

# %%
ul = UserList()
# empty Userlist

# %%
print(type(ul))
# Out:
# <class 'collections.UserList'>

# %%
ul1 = UserList([1,2,3,5,566])

# %%
class mylist(UserList):
     def reverse(self,LS=None):
          raise RuntimeError("NOT POSSIBLE FOR THIS LIST")

# %%
l = [1,2,3,5,566]
l1  = mylist(l)

# %%
l1.reverse()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 60 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y141sZmlsZQ%3D%3D?line=0'>1</a> l1.reverse()
#
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 60 in mylist.reverse(self, LS)
#       <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y141sZmlsZQ%3D%3D?line=1'>2</a> def reverse(self,LS=None):
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y141sZmlsZQ%3D%3D?line=2'>3</a>      raise RuntimeError("NOT POSSIBLE FOR THIS LIST")
#
# RuntimeError: NOT POSSIBLE FOR THIS LIST

# %% [markdown]
# ### UserString
#
# Python supports a String like a container called UserString present in the collections module. This class acts as a wrapper class around the string objects. This class is useful when one wants to create a string of their own with some modified functionality or with some new functionality. It can be considered as a way of adding new behaviors for the string. This class takes any argument that can be converted to string and simulates a string whose content is kept in a regular string. The string is accessible by the data attribute of this class.

# %%
from collections import UserString

# %%
class Us(UserString):
    
    def upper(self,input= None):
        raise RuntimeError("NOPE")

# %%
us1  =Us("ayadyudfu")

# %%
us1.upper()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 65 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y151sZmlsZQ%3D%3D?line=0'>1</a> us1.upper()
#
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 65 in Us.upper(self, input)
#       <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y151sZmlsZQ%3D%3D?line=2'>3</a> def upper(self,input= None):
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y151sZmlsZQ%3D%3D?line=3'>4</a>     raise RuntimeError("NOPE")
#
# RuntimeError: NOPE

# %% [markdown]
# # datetime module
#
# In Python, date and time are not a data type of their own, but a module named datetime can be imported to work with the date as well as time. Python Datetime module comes built into Python, so there is no need to install it externally.
#
# Python Datetime module supplies classes to work with date and time. These classes provide a number of functions to deal with dates, times and time intervals. Date and datetime are an object in Python, so when you manipulate them, you are actually manipulating objects and not string or timestamps.
#
# The DateTime module is categorized into 6 main classes –
#
#     date – An idealized naive date, assuming the current Gregorian calendar always was, and always will be, in effect. Its attributes are year, month and day.
#     time – An idealized time, independent of any particular day, assuming that every day has exactly 24*60*60 seconds. Its attributes are hour, minute, second, microsecond, and tzinfo.
#     datetime – Its a combination of date and time along with the attributes year, month, day, hour, minute, second, microsecond, and tzinfo.
#     timedelta – A duration expressing the difference between two date, time, or datetime instances to microsecond resolution.
#     tzinfo – It provides time zone information objects.
#     timezone – A class that implements the tzinfo abstract base class as a fixed offset from the UTC (New in version 3.2).

# %%
import datetime

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %% [markdown]
# # Date class
# The date class is used to instantiate date objects in Python. When an object of this class is instantiated, it represents a date in the format YYYY-MM-DD. Constructor of this class needs three mandatory arguments year, month and date.
#
# **Constructor syntax:**
#
# <code>class datetime.date(year, month, day)<code>
# ________________________
# The arguments must be in the following range –
#
#     MINYEAR <= year <= MAXYEAR
#     1 <= month <= 12
#     1 <= day <= number of days in the given month and year
#
# Note – If the argument is not an integer it will raise a TypeError and if it is outside the range a ValueError will be raised.

# %%
from datetime import date

# %%
d  = date(2022,8,24)

# %%
d
# Out:
# datetime.date(2022, 8, 24)

# %%
d  = date(20202,8,24)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\PROGAMMING\100 DAYS OF CODE CHALLENGE\DAY-040\DAY-040.ipynb Cell 73 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/PROGAMMING/100%20DAYS%20OF%20CODE%20CHALLENGE/DAY-040/DAY-040.ipynb#Y165sZmlsZQ%3D%3D?line=0'>1</a> d  = date(20202,8,24)
#
# ValueError: year 20202 is out of range

# %% [markdown]
# ## Get Current Date
#
# To return the current local date today() function of date class is used. **today()** function comes with several attributes (year, month and day). These can be printed individually.

# %%
date.today()
# Out:
# datetime.date(2022, 8, 24)

# %%
cd =date.today()

# %%
cd
# Out:
# datetime.date(2022, 8, 24)

# %%
print(f"DATE:{cd.day}\nMONTH:{cd.month}\nYEAR:{cd.year}")
# Out:
# DATE:24
# MONTH:8
# YEAR:2022

# %% [markdown]
# ### Get date from Timestamp
#
# We can create date objects from timestamps y=using the fromtimestamp() method. The timestamp is the number of seconds from 1st January 1970 at UTC to a particular date.

# %%
ts = date.fromtimestamp(99999994)

# %%
ts
# Out:
# datetime.date(1973, 3, 3)

# %%
ts = date.fromtimestamp(0)

# %%
ts
# Out:
# datetime.date(1970, 1, 1)

# %%
# date class attribute
Image("https://i.postimg.cc/L5KpCqmL/Python-Date-Time-Date-Class-Geeksfor-Geeks.png")

# %%
# min
print(date.min)
# max
print(date.max)
#resolution
print(date.resolution)
d = date(2022,8,24)
#year
print(d.year)
#month
print(d.month)
#day
print(d.day)
# Out:
# 0001-01-01
# 9999-12-31
# 1 day, 0:00:00
# 2022
# 8
# 24

# %% [markdown]
# ## date Class Functions
#
#  Date class provides various functions to work with date object, like we can get the today’s date, date from the current timestamp, date from the proleptic Gregorian ordinal, where January 1 of year 1 has ordinal 1, etc. Let’s see the list of all the functions provided by this class –

# %%
Image("https://i.postimg.cc/Df649nxk/Python-Date-Time-Date-Class-Geeksfor-Geeks.png")

# %%
d  = date(2022,8,24)

# %%
d.ctime()
# Out:
# 'Wed Aug 24 00:00:00 2022'

# %%
d  = date(2022,7,24)

# %%
d.ctime()
# 00:00:00 becaus ewe do not set the current time
# Out:
# 'Sun Jul 24 00:00:00 2022'

# %%
d.fromisocalendar(year=2022,week=34,day=3)
# this take the 3args year,week,day
# so it will print the date and month
# Out:
# datetime.date(2022, 8, 24)

# %%
d =date.today()
print(type(d),d)
sd = date.isoformat(d)
print(sd,type(sd))
# Out:
# <class 'datetime.date'> 2022-08-24
# 2022-08-24 <class 'str'>

# %%
print(date.fromordinal(999999))
# Out:
# 2738-11-27

# %%
print(date.fromtimestamp(1661360470))
# it works in Epoch time 
# https://www.epochconverter.com/
# Out:
# 2022-08-24

# %%
print(d.isocalendar())
# Out:
# datetime.IsoCalendarDate(year=2022, week=34, weekday=3)

# %%
# isoformat()
print(d.isoformat())
# Out:
# 2022-08-24

# %%
# isoweekdays()
print(d.isoweekday())
# Out:
# 3

# %%
print(d)
# Out:
# 2022-08-24

# %%
#replace()
d.replace(2024)
# Out:
# datetime.date(2024, 8, 24)

# %%
#timetuple()
d.timetuple()
# Out:
# time.struct_time(tm_year=2022, tm_mon=8, tm_mday=24, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=236, tm_isdst=-1)

# %%
# toordinal()
print(d.toordinal())
# the second verison of today date
# Out:
# 738391

# %%
print(d)
print(d.weekday())
# Out:
# 2022-08-24
# 2
